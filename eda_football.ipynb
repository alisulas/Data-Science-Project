# %%
import numpy as np
import pandas as pd


people_df = pd.read_csv("data/people.csv")

# %%
people_df.head()
# Out:
#                    personId:ID(Person-ID) first_name last_name  \
# 995  b278b907-a893-4c88-9f1f-f05b26d4ede1       Jean    Walter
# 996  a6e7a09a-1258-46f0-bc87-3fb1149a338a     Thomas  Williams
# 997  e5d2b34d-3b55-43d5-bc79-3bdaff5b6a24    Anthony     Smith
# 998  ee003e9d-3b90-4aea-b511-8d57c0d76f41       Sara   Jenkins
# 999  1d81b320-8c78-4a94-ba01-9f93c35bd622  Katherine      Snow
#
#     birth_date:date  age:int                location                 genre  \
# 995      1919-04-10      105      Toledo New York US  Cars and automobiles
# 996      1955-10-12       69        Rolla Chicago US               Fitness
# 997      1929-08-27       95    Woodlawn New York US                   Art
# 998      2011-12-27       13  Collinwood New York US               Science
# 999      1980-02-07       44        Pekin Chicago US               Fitness
#
#      bot_score:float  :LABEL
# 995             0.94  person
# 996             0.62  person
# 997             0.98  person
# ...

# %%
people_df.tail()
# Out:
#                    personId:ID(Person-ID) first_name last_name  \
# 995  b278b907-a893-4c88-9f1f-f05b26d4ede1       Jean    Walter
# 996  a6e7a09a-1258-46f0-bc87-3fb1149a338a     Thomas  Williams
# 997  e5d2b34d-3b55-43d5-bc79-3bdaff5b6a24    Anthony     Smith
# 998  ee003e9d-3b90-4aea-b511-8d57c0d76f41       Sara   Jenkins
# 999  1d81b320-8c78-4a94-ba01-9f93c35bd622  Katherine      Snow
#
#     birth_date:date  age:int                location                 genre  \
# 995      1919-04-10      105      Toledo New York US  Cars and automobiles
# 996      1955-10-12       69        Rolla Chicago US               Fitness
# 997      1929-08-27       95    Woodlawn New York US                   Art
# 998      2011-12-27       13  Collinwood New York US               Science
# 999      1980-02-07       44        Pekin Chicago US               Fitness
#
#      bot_score:float  :LABEL
# 995             0.94  person
# 996             0.62  person
# 997             0.98  person
# ...

# %%
people_df[10:20]
# Out:
#                   personId:ID(Person-ID) first_name last_name birth_date:date  \
# 10  01b180f0-1c3a-465a-8f98-59ae0d3fc6a1      Brian   Schultz      1966-03-09
# 11  ce4552d1-935b-4996-8fa0-53531080c25a        Amy   Wilkins      1960-10-21
# 12  5709ae8c-ca41-46ac-a62d-59b6ccb19ee4      Laura  Williams      2013-09-15
# 13  7d299334-a56d-4fc0-bdc1-91caccf00edc    Anthony      Ryan      1962-08-22
# 14  1a86b6ec-2539-4097-b1d3-590a92fbec9d     Daniel     Davis      1965-12-03
# 15  1584b301-0382-4ba2-b4fe-712b872005fd    Candice     Hardy      1999-03-24
# 16  4c763328-d320-49fb-997f-2694e4b27730      David    Gordon      1955-07-05
# 17  a5e77001-7b9b-418c-86b4-26205630ae10    Timothy       May      1947-08-06
# 18  d1274f87-75d1-4c60-82ac-76b7a1c8ab6e       Anna   Herrera      1980-04-21
# 19  65a2d033-489c-4836-8373-c81b80e7caf8      James   Swanson      1919-07-20
#
#     age:int                      location                genre  \
# ...

# %%
people1_df = people_df[["first_name", "last_name", "genre"]][:500] # first 500 people
people2_df = people_df[["first_name", "last_name", "genre"]][500:] # last 500 people

# %%
people1_df.merge(people2_df, how="inner", left_on="genre", right_on="genre")
# Out:
#      first_name_x last_name_x  genre first_name_y last_name_y
# 0            Mark      Fields  Music        Kylie       Moore
# 1            Mark      Fields  Music      Timothy      Holmes
# 2            Mark      Fields  Music         Luke     Carlson
# 3            Mark      Fields  Music       Leslie      Fields
# 4            Mark      Fields  Music       Steven     Kennedy
# ...           ...         ...    ...          ...         ...
# 8480    Elizabeth      Miller  Books      Kaitlin       Brown
# 8481    Elizabeth      Miller  Books        Sarah        Mayo
# 8482    Elizabeth      Miller  Books    Cassandra        Hess
# 8483    Elizabeth      Miller  Books        James     Herring
# 8484    Elizabeth      Miller  Books        Faith       White
#
# [8485 rows x 5 columns]

# %%
people_df[people_df["location"] == "Rolla Chicago US"]
# Out:
#                    personId:ID(Person-ID) first_name  last_name  \
# 89   f9614ee7-c774-4428-a2d1-6bad9d5afbe1     Brandy     Willis
# 116  454632f2-755a-43e9-965e-4adb05cd291e      Kayla  Blanchard
# 175  9a8934eb-205d-49f0-bffc-a888109c384b     Ronald    Terrell
# 183  d36fa40e-4214-46ea-a8d2-2f94344de2fd      Tracy      Henry
# 226  35a1743b-9019-453d-b59b-4be7bfe9eb0f     Joshua       Hill
# 507  b9020c4d-1a7d-4a02-ab28-1d07b0cbaadb      Tommy     Miller
# 536  7409c4ae-3dd4-4ab1-acb0-bd704aa43da5     Rhonda      Cline
# 637  4b026e90-d57f-475d-9d20-5c8c8bd35d43   Brittany     French
# 676  5aa00d04-d6a2-49ab-b066-0ab8128cc4e5      Susan     Bishop
# 719  90a3cf5b-ec60-427d-ad50-7e399bcab1c3      Megan   Stephens
# 909  d863928e-1ada-49aa-a45d-f89dd764881c      Kathy       Roth
# 950  1cd6cb88-00f5-4432-a369-3bf689935e0d     Ashlee   Phillips
# 982  20ac475d-8830-4df5-8f06-8b9eabfcfc53     Kendra    Wallace
# 996  a6e7a09a-1258-46f0-bc87-3fb1149a338a     Thomas   Williams
#
# ...
